# %% [markdown]
# ```pip install box2d-py``` after installing Visual C++ and rebooting.

# %%
from importlib import reload
import cartpole_lab.charts
reload(cartpole_lab.charts)

import numpy as np
import gym
import cartpole_lab.agent
import cartpole_lab.deeprico
import cartpole_lab.approximator
reload(cartpole_lab.agent)
reload(cartpole_lab.deeprico)
reload(cartpole_lab.approximator)
from cartpole_lab.deeprico import deep_rico

env = gym.make('LunarLander-v2')
observation = env.reset()
# Out:
# Using TensorFlow backend.

# %%
agent = deep_rico(env)
agent.train(500)
# Out:
# avg of last 100 episodes: -126.518837

# %%
agent.policy.model.save(r'models/lander-gamma-095.h5')

# %%
low_gamma = deep_rico(env)
low_gamma.policy.gamma = 0.999
low_gamma.train(200)
# Out:
# avg of last 100 episodes: -568.206607

# %%
low_gamma.train(500, epsilon_decay=0.99999999, epsilon_min=0.02)

# %%
agent.demo()
# Out:
# score= -159.1518484455246
# score= -122.78004225612753
# score= -153.15614864071694
# score= -87.3788574252751
# score= -170.8434546971984
# score= -239.96642993873363
# score= -101.74285008120995
# score= -181.30449669916757
# score= -194.64580286226283
# score= -157.7404737473863
# Avg rewards= -156.87104047936026

# %%
noob = deep_rico(env) # save an untrained one for comparison

# %%
def total_rewards(episode):
    return sum([reward for (state, action, reward, next_state, done) in episode])
        
def run_summary(agent, render=True):
    episode = agent.run_episode(render=render)
    return total_rewards(episode)

def run_episodes(agent, count=10, render=True):
    scores = []
    for _ in range(count):
        score = run_summary(agent, render=render)
        print('score=%f' % score)
        scores.append(score)
    print('Mean score=%f' % np.mean(scores))

# %%
env.close()

# %%
agent.train(500)
# Out:
# avg of last 100 episodes: -185.124037
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-c74fd75a069b> in <module>()
# ----> 1 agent.train(500)
#
# C:\Users\rilack\Documents\jupyter-notebooks\ai-gym-experiments\cartpole_lab\agent.py in train(self, episodes, render, epsilon_start, epsilon_min, epsilon_decay)
#      37         chartfile = r'images/progress.png'
#      38         for _ in log_progress(range(episodes), name='Episodes'):
# ---> 39             episode = self.run_episode(render=render)
#      40             episode_scores.append(total_rewards(episode))
#      41             epsilons.append(self.policy.epsilon)
#
# C:\Users\rilack\Documents\jupyter-notebooks\ai-gym-experiments\cartpole_lab\agent.py in run_episode(self, render)
#      19             state, reward, done, _ = self.env.step(action)
#      20             episode.append((prev_state, prev_action, reward, state, done))
# ---> 21             self.policy.step_completed(prev_state, prev_action, reward, state, done)
#      22             if render:
#      23                 self.env.render()
#
# C:\Users\rilack\Documents\jupyter-notebooks\ai-gym-experiments\cartpole_lab\deeprico.py in step_completed(self, prev_state, prev_action, reward, state, done)
#      54             steps = random.sample(self.snapshots, self.batch_size)
#      55             for (prev_state, prev_action, reward, state, done) in steps:
# ---> 56                 self._learn_step(prev_state, prev_action, reward, state, done)
#      57
#      58     def _learn_step(self, prev_state, prev_action, reward, state, done):
#
# C:\Users\rilack\Documents\jupyter-notebooks\ai-gym-experiments\cartpole_lab\deeprico.py in _learn_step(self, prev_state, prev_action, reward, state, done)
#      57
#      58     def _learn_step(self, prev_state, prev_action, reward, state, done):
# ---> 59         rewards_all = self.model.predict(prev_state)
#      60         if done:
#      61             future_rewards = 0
#
# C:\Users\rilack\Documents\jupyter-notebooks\ai-gym-experiments\cartpole_lab\approximator.py in predict(self, X)
#      35         X: one set of X values to predict. X shape is (num_inputs,).
#      36         """
# ---> 37         predictions = self.predict_multi(np.array([X])) # An array for m input values.
#      38         return predictions[0] # We have a batch size of one here; return the first.
#      39
#
# C:\Users\rilack\Documents\jupyter-notebooks\ai-gym-experiments\cartpole_lab\approximator.py in predict_multi(self, X_batch)
#      21         where m is the number of items you'd like to predict.
#      22         """
# ---> 23         return self.model.predict(X_batch)
#      24
#      25     def train_multi(self, X, Y, batch_size=16, epochs=1, verbose=0):
#
# C:\Users\rilack\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1165                                             batch_size=batch_size,
#    1166                                             verbose=verbose,
# -> 1167                                             steps=steps)
#    1168
#    1169     def train_on_batch(self, x, y,
#
# C:\Users\rilack\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# C:\Users\rilack\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# C:\Users\rilack\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# C:\Users\rilack\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1380           ret = tf_session.TF_SessionRunCallable(
#    1381               self._session._session, self._handle, args, status,
# -> 1382               run_metadata_ptr)
#    1383         if run_metadata:
#    1384           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
run_episodes(agent, count=5)
# Out:
# score=-382.065324
# score=-298.185657
# score=-110.661777
# score=-540.666944
# score=-64.293288
# Mean score=-279.174598

# %%
agent.policy.peek()
# Out:
# array([4.2793612, 4.8437734, 4.198536 , 4.87267  ], dtype=float32)

# %%
agent.train(200,render=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-fc3f89e473ab> in <module>
# ----> 1 agent.train(200,render=True)
#
# ~\Documents\notebooks\ai-gym-experiments\cartpole_lab\agent.py in train(self, episodes, render, epsilon_start, epsilon_min, epsilon_decay)
#      43             now = time.time()
#      44             if now - last_update_time > image_update_seconds:
# ---> 45                 plot_episode_lengths(episode_lengths, epsilons, save=chartfile)
#      46                 last_update_time = now
#      47
#
# ~\Documents\notebooks\ai-gym-experiments\cartpole_lab\charts.py in plot_episode_lengths(episode_lengths, epsilons, save)
#      44
#      45     avg_width = int(len(episode_lengths)/4)
# ---> 46     ax1.plot(moving_average(episode_lengths, window_width=avg_width), color='black', linestyle='--')
#      47     #handles, labels = ax1.get_legend_handles_labels()
#      48
#
# ~\Documents\notebooks\ai-gym-experiments\cartpole_lab\charts.py in moving_average(data, window_width)
#      73     w = window_width
#      74     cumulative = np.cumsum(np.insert(data, 0, 0))
# ---> 75     avg_vec = (cumulative[w:] - cumulative[:-w]) / w
#      76     return avg_vec
#
# ValueError: operands could not be broadcast together with shapes (3,) (0,)

# %%
a = [1,2,3,4]
a[1:-2]
# Out:
# [2]

# %%
len(agent.policy.snapshots)
# Out:
# 109055

# %%
agent.policy.snapshots[0:10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-b0afe1e611b2> in <module>()
# ----> 1 agent.policy.snapshots[0:10]
#
# TypeError: sequence index must be integer, not 'slice'

# %%
agent.policy.peek()
# Out:
# array([ 4.80480051,  4.95879793,  4.47204924,  4.80873108], dtype=float32)
